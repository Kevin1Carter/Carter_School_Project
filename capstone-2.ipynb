# %%
import os
import pandas as pd

# %%
#Data Collection
df = pd.read_csv(r'C:\Users\kevin\OneDrive\Documents\average_hours_for_child_protective_services_to_respond_to_maltreatment_referral_usafacts.csv', index_col=False)
df = pd.DataFrame(df)
df = df.transpose()
df.head()
# Out:
#                                                       0             1   \
# Years  Average hours for Child Protective Services to...      By State
# 2000                                                  54           NaN
# 2001                                                 NaN           NaN
# 2002                                                 NaN           NaN
# 2003                                                 NaN           NaN
#
#                     2               3                4                 5   \
# Years          Alabama          Alaska          Arizona          Arkansas
# 2000               NaN             NaN              NaN               NaN
# 2001               NaN             NaN              NaN               NaN
# 2002               NaN             NaN              NaN               NaN
# 2003               NaN             NaN              NaN               NaN
#
#                        6                 7                    8   \
# ...

# %%
df.head(10)
# Out:
#                                                       0             1   \
# Years  Average hours for Child Protective Services to...      By State
# 2000                                                  54           NaN
# 2001                                                 NaN           NaN
# 2002                                                 NaN           NaN
# 2003                                                 NaN           NaN
# 2004                                                 NaN           NaN
# 2005                                                  89           NaN
# 2006                                                  84           NaN
# 2007                                                80.0           NaN
# 2008                                                79.0           NaN
#
#                     2               3                4                 5   \
# Years          Alabama          Alaska          Arizona          Arkansas
# ...

# %%
#Filled the NaN data with '0'
df = df.fillna(0)
df.head()
# Out:
#                                                       0             1   \
# Years  Average hours for Child Protective Services to...      By State
# 2000                                                  54             0
# 2001                                                   0             0
# 2002                                                   0             0
# 2003                                                   0             0
#
#                     2               3                4                 5   \
# Years          Alabama          Alaska          Arizona          Arkansas
# 2000                 0               0                0                 0
# 2001                 0               0                0                 0
# 2002                 0               0                0                 0
# 2003                 0               0                0                 0
#
#                        6                 7                    8   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Years to 2020
# Data columns (total 59 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22 non-null     object
#  1   1       22 non-null     object
#  2   2       22 non-null     object
#  3   3       22 non-null     object
#  4   4       22 non-null     object
#  5   5       22 non-null     object
#  6   6       22 non-null     object
#  7   7       22 non-null     object
#  8   8       22 non-null     object
#  9   9       22 non-null     object
#  10  10      22 non-null     object
#  11  11      22 non-null     object
#  12  12      22 non-null     object
#  13  13      22 non-null     object
#  14  14      22 non-null     object
#  15  15      22 non-null     object
#  16  16      22 non-null     object
#  17  17      22 non-null     object
#  18  18      22 non-null     object
#  19  19      22 non-null     object
#  20  20      22 non-null     object
# ...

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=59, step=1)

# %%
df.index
# Out:
# Index(['Years', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
#Dropped the years that had no data
df = df.drop(['2000', '2001', '2002', '2003', '2004'])

# %%
df.head()
# Out:
#                                                       0             1   \
# Years  Average hours for Child Protective Services to...      By State
# 2005                                                  89             0
# 2006                                                  84             0
# 2007                                                80.0             0
# 2008                                                79.0             0
#
#                     2               3                4                 5   \
# Years          Alabama          Alaska          Arizona          Arkansas
# 2005                 0               0               76               189
# 2006                 0             199               47               208
# 2007                 0               0             59.0             223.0
# 2008              24.0               0             70.0             122.0
#
#                        6                 7                    8   \
# ...

# %%
df2 = df.transpose()
df2 = df2.set_index(['Years'])
df2.head()
# Out:
#                                                    2005 2006  2007  2008  \
# Years
# Average hours for Child Protective Services to ...   89   84  80.0  79.0
#     By State                                          0    0     0     0
#         Alabama                                       0    0     0  24.0
#         Alaska                                        0  199     0     0
#         Arizona                                      76   47  59.0  70.0
#
#                                                     2009  2010  2011  2012  \
# Years
# Average hours for Child Protective Services to ...  69.0  71.0  73.0  70.0
#     By State                                           0     0     0     0
#         Alabama                                     24.0  45.0  42.0  42.0
#         Alaska                                         0     0     0     0
#         Arizona                                     80.0     0     0     0
#
# ...

# %%
df2.mean()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_15728\3587575296.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.mean()
# 2007    41.847458
# 2008    48.288136
# 2009    45.864407
# 2010    42.152542
# 2011    41.847458
# 2012    41.508475
# 2013    41.762712
# 2014    49.830508
# 2015    55.389831
# 2016    49.152542
# 2017    50.169492
# 2018    62.067797
# 2019    67.745763
# 2020    65.152542
# dtype: float64

# %%
df2.index
# Out:
# Index(['Average hours for Child Protective Services to respond to maltreatment referral',
#                                                                           '    By State',
#                                                                        '        Alabama',
#                                                                         '        Alaska',
#                                                                        '        Arizona',
#                                                                       '        Arkansas',
#                                                                     '        California',
#                                                                       '        Colorado',
#                                                                    '        Connecticut',
#                                                                       '        Delaware',
# ...

# %%
df3= df2.set_index('2007').groupby('2007').mean()
print(df3)
# Out:
#              2008        2009        2010        2011        2012    2013  \
# 2007
# 0.0     14.357143   14.428571   16.571429   19.785714   15.142857   34.75
# 9.0     11.000000    9.000000    9.000000   10.000000    9.000000   10.00
# 12.0    14.000000   13.000000   13.000000   13.000000   17.000000    0.00
# 22.0    21.000000   13.000000   13.000000   15.000000   19.000000   13.00
# 24.0    24.000000   24.000000   24.000000   24.000000   24.000000   24.00
# 25.0    35.000000   26.000000   25.000000   26.000000   22.000000   25.00
# 26.0    22.000000   17.000000   20.000000   18.000000   18.000000   17.00
# 28.0    26.000000   25.000000   25.000000   18.000000   16.000000   17.00
# 33.0    26.000000   15.000000   13.000000   13.000000   15.000000   12.00
# 38.0    38.500000   36.500000   19.000000   20.000000   19.500000   20.50
# 55.0    46.000000   41.000000   38.000000   37.000000   38.000000   55.00
# 59.0    70.000000   80.000000    0.000000    0.000000    0.000000    0.00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df4= df.set_index('Florida').groupby('Florida').mean()
#       2 print(df4)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
# ...
